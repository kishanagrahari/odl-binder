# %% [markdown]
# # 🧠 ODL Demo Notebook
#
# This notebook runs the ODL HBP training after patching Keras with the custom `training.py`.

# %%
# 🔁 Replace training.py manually at runtime
# !cp ODL/training.py /usr/local/lib/python2.7/site-packages/keras/training.py

# %%
# ▶️ Run the ODL HBP experiment
# !cd ODL/src/hbp && python main.py -c hb19.yaml
